# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
incomes = np.random.normal(10,20,10000)
plt.hist(incomes,50)
plt.show()

# %%
incomes.std()
# Out:
# 20.043200168792033

# %%
incomes.var()
# Out:
# 401.72987300626494
