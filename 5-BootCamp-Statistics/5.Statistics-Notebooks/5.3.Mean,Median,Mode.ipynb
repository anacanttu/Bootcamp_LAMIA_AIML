# %%
import numpy as np
incomes = np.random.normal(27000,15000,10000)
np.mean(incomes)
# Out:
# 27131.603714113753

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %%
np.median(incomes)
# Out:
# 27200.899327317493

# %%
incomes = np.append(incomes,[1000000000])

# %%
np.median(incomes)
# Out:
# 27201.3059430767

# %%
np.mean(incomes)
# Out:
# 127118.89182493127

# %% [markdown]
# # Mode

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([72, 67, 46, 44, 48, 67, 54, 74, 43, 37, 22, 38, 87, 73, 27, 49, 84,
#        54, 73, 87, 71, 32, 69, 75, 24, 72, 36, 19, 31, 66, 22, 64, 35, 23,
#        83, 84, 84, 75, 73, 63, 86, 79, 43, 28, 50, 28, 52, 39, 35, 22, 53,
#        33, 54, 68, 43, 22, 26, 42, 51, 79, 18, 39, 29, 65, 20, 32, 24, 40,
#        64, 21, 18, 19, 87, 50, 79, 56, 41, 70, 40, 83, 42, 88, 21, 42, 42,
#        81, 57, 18, 43, 64, 46, 89, 31, 41, 86, 44, 60, 35, 73, 64, 83, 46,
#        42, 45, 44, 38, 18, 72, 68, 64, 40, 26, 61, 68, 33, 49, 38, 82, 43,
#        69, 69, 41, 23, 56, 41, 66, 64, 31, 39, 59, 30, 57, 51, 36, 87, 82,
#        47, 44, 64, 41, 20, 87, 52, 19, 25, 38, 22, 38, 36, 32, 53, 65, 56,
#        28, 60, 33, 54, 67, 34, 28, 29, 20, 46, 60, 88, 49, 42, 51, 77, 73,
#        43, 86, 40, 89, 21, 29, 27, 40, 40, 43, 71, 42, 37, 59, 47, 23, 72,
#        27, 43, 41, 26, 21, 45, 76, 53, 36, 40, 18, 41, 79, 18, 84, 59, 51,
#        66, 54, 71, 65, 62, 78, 68, 40, 65, 52, 37, 49, 25, 69, 57, 38, 69,
#        27, 24, 84, 42, 75, 21, 36, 57, 81, 70, 77, 79, 64, 71, 48, 42, 70,
#        27, 32, 56, 34, 58, 89, 19, 30, 81, 39, 32, 20, 47, 31, 76, 66, 70,
#        88, 81, 51, 61, 84, 68, 26, 89, 49, 53, 78, 52, 46, 81, 38, 39, 40,
#        69, 63, 35, 33, 47, 83, 42, 56, 49, 87, 18, 81, 50, 85, 38, 86, 21,
#        35, 78, 29, 89, 86, 87, 51, 34, 69, 62, 53, 48, 59, 83, 85, 80, 39,
#        84, 24, 28, 44, 76, 55, 67, 27, 63, 79, 31, 34, 62, 67, 87, 67, 55,
#        53, 36, 55, 61, 19, 43, 49, 59, 26, 42, 51, 30, 69, 80, 77, 69, 45,
#        63, 47, 30, 71, 75, 83, 58, 73, 59, 49, 32, 28, 29, 30, 50, 36, 72,
#        34, 31, 28, 54, 86, 24, 62, 31, 18, 82, 37, 46, 59, 73, 85, 31, 46,
#        84, 43, 25, 37, 70, 40, 45, 40, 43, 51, 70, 23, 50, 25, 55, 48, 76,
#        81, 71, 89, 77, 39, 41, 47, 65, 75, 37, 51, 27, 78, 54, 88, 30, 29,
#        37, 28, 58, 53, 79, 51, 47, 65, 88, 78, 43, 59, 47, 36, 26, 84, 32,
#        32, 72, 29, 33, 47, 65, 49, 31, 18, 29, 30, 29, 61, 30, 21, 87, 51,
#        32, 58, 37, 46, 22, 57, 22, 56, 20, 49, 49, 30, 39, 51, 44, 27, 55,
#        37, 84, 23, 19, 67, 37, 43, 69, 81, 75, 69, 38, 74, 36, 82, 30, 53,
#        44, 32, 53, 75, 76, 60, 32, 54, 87, 48, 35, 66, 40, 52, 37, 52, 34,
#        37, 67, 49, 50, 61, 35, 77])

# %%
from scipy import stats

# %%
stats.mode(ages)
# Out:
# ModeResult(mode=43, count=13)
